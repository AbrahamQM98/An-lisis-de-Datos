# %%
import folium

from folium.plugins import minimap
from folium.plugins import MiniMap
from branca.element import Figure

# %%
CR=folium.Map(location=[9.986495749499337, -84.10997089042833],zoom_start=16,titles='stamenterrain')
Campus_Benjamin='<b>C. Benjamin Nuñez</b>'
Campus_Coto='<b>C. Coto</b>'
Campus_O_Dengo='<b>C. Omar Dengo</b>'
Campus_Liberia='<b>C. Liberia</b>'
Campus_PZ='<b>C. Perez Zeledon</b>'

folium.Marker(location=[9.970061527856307, -84.12904580392255],popup=Campus_Benjamin,icon=folium.Icon(color="orange",icon="ok-sign")).add_to(CR)

folium.Circle(location=[9.970061527856307, -84.12904580392255],popup=Campus_Benjamin,color='purple', weight=6,fill_color='red',fill_opacity=0.5,tooltip='Casa').add_to(CR)


folium.Marker(location=[8.573546061478, -82.87237023091987],popup=Campus_Coto,icon=folium.Icon(color="green",icon="ok-sign")).add_to(CR)

folium.Circle(location=[8.573546061478, -82.87237023091987],popup=Campus_Coto,color='brown', weight=6,fill_color='red',fill_opacity=0.5,tooltip='Casa').add_to(CR)


folium.Marker(location=[9.99866793732291, -84.11124430576928],popup=Campus_O_Dengo,icon=folium.Icon(color="red",icon="ok-sign")).add_to(CR)

folium.Circle(location=[9.99866793732291, -84.11124430576928],popup=Campus_O_Dengo,color='black', weight=6,fill_color='red',fill_opacity=0.5,tooltip='Casa').add_to(CR)


folium.Marker(location=[10.617707192433766, -85.4513429020708],popup=Campus_Liberia,icon=folium.Icon(color="purple",icon="ok-sign")).add_to(CR)

folium.Circle(location=[10.617707192433766, -85.4513429020708],popup=Campus_Liberia,color='blue', weight=6,fill_color='red',fill_opacity=0.5,tooltip='Casa').add_to(CR)


folium.Marker(location=[9.380010896121437, -83.69148201742081],popup=Campus_PZ,icon=folium.Icon(color="blue",icon="ok-sign")).add_to(CR)

folium.Circle(location=[9.380010896121437, -83.69148201742081],popup=Campus_PZ,color='black', weight=6,fill_color='red',fill_opacity=0.5,tooltip='Casa').add_to(CR)



minimap=MiniMap(title_layer='stamenterrain',position='bottomright')

CR.add_child(minimap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cb4596b53398e673e76683a18a15c01 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cb4596b53398e673e76683a18a15c01&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cb4596b53398e673e76683a18a15c01 = L.map(
#                 &quot;map_0cb4596b53398e673e76683a18a15c01&quot;,
#                 {
#                     center: [9.986495749499337, -84.10997089042833],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;stamenterrain&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9cc72436be2d471fcc43fd09fe34522d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0cb4596b53398e673e76683a18a15c01);
#
#
#             var marker_be602bf78f6bee1130baafcacedf76da = L.marker(
#                 [9.970061527856307, -84.12904580392255],
#                 {}
#             ).addTo(map_0cb4596b53398e673e76683a18a15c01);
#
#
#             var icon_61f26d06b08b1f4490974e39c2bc3944 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_be602bf78f6bee1130baafcacedf76da.setIcon(icon_61f26d06b08b1f4490974e39c2bc3944);
#
#
#         var popup_139d0ea5264d2e706428607ac5273c86 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_07c00c6bee299359b7ebbb8c8a53fc1d = $(`&lt;div id=&quot;html_07c00c6bee299359b7ebbb8c8a53fc1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;C. Benjamin Nuñez&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_139d0ea5264d2e706428607ac5273c86.setContent(html_07c00c6bee299359b7ebbb8c8a53fc1d);
#
#
#
#         marker_be602bf78f6bee1130baafcacedf76da.bindPopup(popup_139d0ea5264d2e706428607ac5273c86)
#         ;
#
#
#
#
#             var circle_a397daa4d2ba34b9aed9ef8c8ee28f5b = L.circle(
#                 [9.970061527856307, -84.12904580392255],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_0cb4596b53398e673e76683a18a15c01);
#
#
#         var popup_bf154fabe5bf4a490f7017f98784d07c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a67e0066d6e6b0ee4210d21813c5c34 = $(`&lt;div id=&quot;html_0a67e0066d6e6b0ee4210d21813c5c34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;C. Benjamin Nuñez&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_bf154fabe5bf4a490f7017f98784d07c.setContent(html_0a67e0066d6e6b0ee4210d21813c5c34);
#
#
#
#         circle_a397daa4d2ba34b9aed9ef8c8ee28f5b.bindPopup(popup_bf154fabe5bf4a490f7017f98784d07c)
#         ;
#
#
#
#
#             circle_a397daa4d2ba34b9aed9ef8c8ee28f5b.bindTooltip(
#                 `&lt;div&gt;
#                      Casa
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e0b4255b184d35b381f8b96b2f759633 = L.marker(
#                 [8.573546061478, -82.87237023091987],
#                 {}
#             ).addTo(map_0cb4596b53398e673e76683a18a15c01);
#
#
#             var icon_cd0d13ad23d693893b2538f355d4bfdb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e0b4255b184d35b381f8b96b2f759633.setIcon(icon_cd0d13ad23d693893b2538f355d4bfdb);
#
#
#         var popup_a989140c7819a9737d414380d4c24633 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c9455b315d293706b8f44e51d5aa8c28 = $(`&lt;div id=&quot;html_c9455b315d293706b8f44e51d5aa8c28&quot; style=&quot;width: 100.0%; height: 100.0%;&qu
